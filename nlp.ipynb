# %%
print("hello world")

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt_tab')
mytext = """In the previous chapter, we saw examples of some common NLP 
applications that we might encounter in everyday life. If we were asked to 
build such an application, think about how we would approach doing so at our 
organization. We would normally walk through the requirements and break the 
problem down into several sub-problems, then try to develop a step-by-step 
procedure to solve them. Since language processing is involved, we would also
list all the forms of text processing need.""" 
my_sentences = sent_tokenize(mytext)
print(my_sentences)

# %%
import nltk
from nltk.stem import PorterStemmer

# init stemmer
porter_stemmer=PorterStemmer()
# stem connect variations
words=["connect","connected","connection","connections","connects"]
stemmed_words=[porter_stemmer.stem(word=word) for word in words]

print(words)
print(stemmed_words)

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

# init lemmatizer
lemmatizer = WordNetLemmatizer() 
words=["trouble","troubling","troubled","troubles","dogs", "cats"]
lemmatized_words=[lemmatizer.lemmatize(word=word,pos='v') for word in words]
print(words, lemmatized_words)

# %%
sentence = "Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, especially computer systems. These processes include learning (acquiring information and rules for using it), reasoning (using rules to reach approximate or definite conclusions), and self-correction."
processed_text = (sentence)
print("".join(processed_text))

# %%
import nltk
from nltk.stem import PorterStemmer

# init stemmer
porter_stemmer = PorterStemmer()

# stem connect variations
words = ["simulate", "simulated", "simulation", "simulations", "simulats"]
words1 = ["learn", "learned", "learning", "learnings", "learns"]
words2 = ["reason", "reasoned", "reasoning", "reasonings", "reasons"]

stemmed_words = [porter_stemmer.stem(word) for word in words]
stemmed_words1 = [porter_stemmer.stem(word) for word in words1]
stemmed_words2 = [porter_stemmer.stem(word) for word in words2]

print("Original words:", words)
print("Stemmed words:", stemmed_words)

print("Original words1:", words1)
print("Stemmed words1:", stemmed_words1)

print("Original words2:", words2)
print("Stemmed words2:", stemmed_words2)

# %%
import nltk
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Sample text
mytext = """Artificial intelligence and machine learning are shaping the future of technology. 
These technologies help automate tasks, improve efficiency, and create innovative solutions in various fields. 
For instance, recommendation systems and virtual assistants rely on these technologies to deliver personalized experiences."""

# Tokenization
sentences = sent_tokenize(mytext)
print("Tokenized Sentences:")
print(sentences)

# Tokenize into words
words = word_tokenize(mytext)

# Stemming
porter_stemmer = PorterStemmer()
stemmed_words = [porter_stemmer.stem(word) for word in words]
stem_df = pd.DataFrame({'Original Word': words, 'Stemmed Word': stemmed_words})
print("\nStemming Example:")
print(stem_df)

# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]
lemmatized_df = pd.DataFrame({'Original Word': words, 'Lemmatized Word': lemmatized_words})
print("\nLemmatization Example:")
print(lemmatized_df)
# Out:
# Tokenized Sentences:
# ['Artificial intelligence and machine learning are shaping the future of technology.', 'These technologies help automate tasks, improve efficiency, and create innovative solutions in various fields.', 'For instance, recommendation systems and virtual assistants rely on these technologies to deliver personalized experiences.']
#
# Stemming Example:
#      Original Word Stemmed Word
# 0       Artificial     artifici
# 1     intelligence     intellig
# 2              and          and
# 3          machine       machin
# 4         learning        learn
# 5              are          are
# 6          shaping        shape
# 7              the          the
# 8           future        futur
# 9               of           of
# 10      technology    technolog
# 11               .            .
# 12           These        these
# 13    technologies    technolog
# 14            help         help
# 15        automate        autom
# 16           tasks         task
# 17               ,            ,
# 18         improve       improv
# 19      efficiency       effici
# 20               ,            ,
# 21             and          and
# 22          create        creat
# 23      innovative        innov
# 24       solutions        solut
# 25              in           in
# 26         various       variou
# 27          fields        field
# 28               .            .
# 29             For          for
# 30        instance      instanc
# 31               ,            ,
# 32  recommendation    recommend
# 33         systems       system
# 34             and          and
# 35         virtual      virtual
# 36      assistants       assist
# 37            rely         reli
# 38              on           on
# 39           these        these
# 40    technologies    technolog
# 41              to           to
# 42         deliver        deliv
# 43    personalized       person
# 44     experiences       experi
# 45               .            .
#
# Lemmatization Example:
#      Original Word Lemmatized Word
# 0       Artificial      Artificial
# 1     intelligence    intelligence
# 2              and             and
# 3          machine         machine
# 4         learning           learn
# 5              are              be
# 6          shaping           shape
# 7              the             the
# 8           future          future
# 9               of              of
# 10      technology      technology
# 11               .               .
# 12           These           These
# 13    technologies    technologies
# 14            help            help
# 15        automate        automate
# 16           tasks            task
# 17               ,               ,
# 18         improve         improve
# 19      efficiency      efficiency
# 20               ,               ,
# 21             and             and
# 22          create          create
# 23      innovative      innovative
# 24       solutions       solutions
# 25              in              in
# 26         various         various
# 27          fields           field
# 28               .               .
# 29             For             For
# 30        instance        instance
# 31               ,               ,
# 32  recommendation  recommendation
# 33         systems         systems
# 34             and             and
# 35         virtual         virtual
# 36      assistants      assistants
# 37            rely            rely
# 38              on              on
# 39           these           these
# 40    technologies    technologies
# 41              to              to
# 42         deliver         deliver
# 43    personalized     personalize
# 44     experiences      experience
# 45               .               .
